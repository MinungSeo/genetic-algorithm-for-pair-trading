# %%
import pandas as pd
import numpy as np
import warnings
import pyodbc
import random
import os
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from collections import Counter
import multiprocessing as mp
import ray
import datetime

warnings.filterwarnings(action = 'ignore')
# Out:
# 2023-12-06 08:12:01,962	INFO util.py:159 -- Outdated packages:
#   ipywidgets==7.6.3 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# #### 유전 알고리즘 활용한 페어 트레이딩_섹터 확장_v1
#
# * v8
#  - 비중 제한 없애기
#  - child 생성 시 볼린저 밴드 계산 기간과 비중 모두 BLX-alpha crossover 적용
#  - mutation 시 랜덤넘버 생성을 통해 각 파라미터에 더하기
#  - 변이 이후 수선 기능 추가. 1) 롱/숏 비중 각 1로 맞추기
#  - train set 기간 0.7에 대해 시뮬레이션 해보기
#  - 정상성 테스트 제외: rolling base 기반 표준화를 사용하기 때문

# %%
conn_pcor = pyodbc.connect('driver={Oracle in OraClient18Home1};dbq=PCOR;uid=EF0SEL;pwd=EF0SEL#076')
conn_quant = pyodbc.connect('driver={SQL Server};server=46.2.90.172;database=quant;uid=index;pwd=samsung@00')
conn_wisefn = pyodbc.connect('driver={SQL Server};server=46.2.90.172;database=wisefn;uid=index;pwd=samsung@00')

# %%
os.chdir("..")
os.chdir("..")

os.chdir('00_data')

#df_const = pd.read_json('230927_index_constituent.json')
df_prc_raw = pd.read_json('230927_stk_prc_daily.json')
#df_turnover = pd.read_json('230927_stk_turnover.json')
#df_sector = pd.read_json('230927_stk_sector.json')
df_mktcap = pd.read_json('230927_stk_mktcap.json')
#df_turnover_daily = pd.read_json('231011_stk_turnover_daily.json')

os.chdir("..")
os.chdir('02_Trading Strategies')
os.chdir('231026_유전 알고리즘을 활용한 페어트레이딩')

# %%
sector_code = 'IKS013'

# %%
sql_dt = f'''
        SELECT TRD_DT, CLOSE_PRC
        FROM TS_IDX_DAILY
        WHERE 1=1
        AND SEC_CD = '{sector_code}'
        AND TRD_DT > '20091231'
        ORDER BY TRD_DT ASC
'''

df_dt = pd.read_sql(sql_dt, conn_wisefn)

# %%
df_dt['TRD_DT'] =  pd.to_datetime(df_dt['TRD_DT'])
df_dt['M'] = df_dt['TRD_DT'].dt.to_period('M')
dt_m = [max(df_dt[df_dt['M']==p]['TRD_DT']) for p in df_dt['M'].unique()]
dt_m = [int(x.strftime('%Y%m%d')) for x in dt_m]

# %%
def objective_func(df, params):
    
    #stk_list = sorted(list(set(df['COMP_CD'])))
    
    params_period = params[0]
    params_init = params[1]
    params_exit = params[2]
    params_wt = params[3:]

    df_sp = np.log(df) * params_wt
    df_sp = df_sp.sum(axis=1)
    
    df_sp_norm = (df_sp - df_sp.rolling(params_period).mean())/df_sp.rolling(params_period).std()
    df_sp_norm.dropna(axis=0, inplace=True)
    
    init_dt = []
    exit_dt = []
    init_yn = 0
    for i in range(len(df_sp_norm)):
        if init_yn == 0:
            if df_sp_norm.iloc[i] < params_init:
                init_dt.append(df_sp_norm.index[i])
                init_yn = 1
        
        elif init_yn == 1:
            if df_sp_norm.iloc[i] > params_exit:
                exit_dt.append(df_sp_norm.index[i])
                init_yn = 0
        
    if len(init_dt) > len(exit_dt):
        if len(init_dt) - len(exit_dt) > 1:
            print("error")
        else:
            init_dt = init_dt[:-1]
    
    ret_list = []
    cum_ret = 1
    for i in range(len(init_dt)):
        dt_1 = init_dt[i]
        dt_2 = exit_dt[i]
        
        prc_1 = df.loc[dt_1]
        prc_2 = df.loc[dt_2]
        
        ret = prc_2/prc_1 - 1
        ret = (ret * params_wt).sum()
        ret_list.append(ret)
        cum_ret *= (1+ret)
    
    return cum_ret

# %%
def generate_weight(length):
    
    pos_len = random.randint(1,length - 1)
    neg_len = length - pos_len
    
    pos_wt = []
    for i in range(pos_len):
        p = random.uniform(0,1)
        pos_wt.append(p)
    
    pos_wt = [x/sum(pos_wt) for x in pos_wt]
    
    neg_wt = []
    for i in range(neg_len):
        n = random.uniform(0,1)
        neg_wt.append(n)
    
    neg_wt = [-x/sum(neg_wt) for x in neg_wt]
    
    wt = pos_wt + neg_wt
    
    random.shuffle(wt)
    
    return wt  
        

def generate_params(df, length):
    
    params_period = random.randint(20,20*24)
    params_init = random.uniform(-4,0)
    params_exit = random.uniform(0,4)
    params_wt = generate_weight(length)
    
    params = [params_period, params_init, params_exit, *params_wt]
            
    return params

# %%
def generate_pop(df, size, length):
    population = []
    
    for i in range(size):
        
        params = generate_params(df,length)
        population.append(params)
        
    return population

# %%
def compute_performance(df, population):
    
    obj_list = []
    for individual in population:
        obj = objective_func(df, individual)
        obj_list.append([individual,obj])
    
    pop_sorted = sorted(obj_list, key=lambda x: x[1], reverse=True)
    
    return pop_sorted

# %%
def select_survivors(population_sorted, best_sample, lucky_few, length, df):
    
    next_gen = []
    
    for i in range(best_sample):
        if population_sorted[i][1] > 0:
            next_gen.append(population_sorted[i][0])
    
    lucky_index = np.random.choice(list(range(len(population_sorted))), lucky_few, replace=False)
    for i in lucky_index:
        next_gen.append(population_sorted[i][0])
    
    next_gen_2 = []
    for item in next_gen:
        if item not in next_gen_2:
            next_gen_2.append(item)
    
    
    while len(next_gen_2) < best_sample + lucky_few:
        next_gen_2.append(generate_params(df, length))
        
    random.shuffle(next_gen_2)
    
    return next_gen_2

# %%
def create_child(param1, param2, alpha):
    
    child = param1.copy()
    
    for i in range(len(child)):
        
        dist = abs(param1[i]-param2[i])
        
        l = min(param1[i],param2[i]) - alpha * dist
        u = max(param1[i],param2[i]) + alpha * dist

        child[i] = l + random.random() * (u-l)
    
    child[0] = int(np.round(child[0]))
    child[0] = min(20*24, child[0])
    child[0] = max(20, child[0])
    
    return child


def create_children(df, population, n_child, alpha, r_param):
    
    k = 0
    children = []

    fitness = [objective_func(df, x) for x in population]
    roulette = [x - min(fitness) + (max(fitness) - min(fitness))/(r_param - 1) for x in fitness]
    #fitness_2 = [x if x >= 0 else 0 for x in fitness]
    
    prob = [x/sum(roulette) for x in roulette]
    
    while k < n_child:
        try:
            sample = np.random.choice(list(range(len(prob))), 2, replace=True, p = prob)
        except:
            sample = np.random.choice(list(range(len(prob))), 2, replace=True)
        parents = [population[sample[0]], population[sample[1]]]
        
        child = create_child(parents[0], parents[1], alpha)
        children.append(child)
        
        k += 1

    return children

# %%
def mutation1(param, prob):
    
    r1 = random.random()
    
    param_mutate = param.copy()
    
    if r1 < prob:
        m1 = np.random.normal(0, 30)
        new_period = m1 + param[0]
        new_period = max(20, new_period)
        new_period = min(20*24, new_period)
        
        param_mutate[0] = int(np.round(new_period))
        
        m2 = np.random.normal(0,0.02,len(param) - 1)
        param_mutate[1:] = [x+y for (x,y) in zip(param_mutate[1:], m2)]
    
    return param_mutate


################################################
def mutate_pop(population, prob1):
    
    for i in range(len(population)):
        population[i] = mutation1(population[i], prob1)
    
    return population

# %%
def fix_1(population, df, length):
    
    # 수선: 비중 조절
    
    fixed_pop = []
    
    for child in population:
    
        child_wt = child[3:]
        child_pos = [x if x >= 0 else 0 for x in child_wt]
        child_neg = [x if x < 0 else 0 for x in child_wt]

        try:
            child_pos_adj = [x/sum(child_pos) for x in child_pos]
            child_neg_adj = [-x/sum(child_neg) for x in child_neg]
            child_wt_adj = [x+y for (x,y) in zip(child_pos_adj, child_neg_adj)]
            adj_child = child[:3] + child_wt_adj
        
        except:
            new_wt = generate_params(df, length)[3:]
            adj_child = child[:3] + new_wt
        
        fixed_pop.append(adj_child)
    
    return fixed_pop

# %%
def simulation_func(df, params):
    
    #stk_list = sorted(list(set(df['COMP_CD'])))
    
    params_period = params[0]
    params_init = params[1]
    params_exit = params[2]
    params_wt = params[3:]

    df_sp = np.log(df) * params_wt
    df_sp = df_sp.sum(axis=1)
    
    df_sp_norm = (df_sp - df_sp.rolling(params_period).mean())/df_sp.rolling(params_period).std()
    df_sp_norm.dropna(axis=0, inplace=True)
    
    init_dt = []
    exit_dt = []
    init_yn = 0
    for i in range(len(df_sp_norm)):
        if init_yn == 0:
            if df_sp_norm.iloc[i] < params_init:
                init_dt.append(df_sp_norm.index[i])
                init_yn = 1
        
        elif init_yn == 1:
            if df_sp_norm.iloc[i] > params_exit:
                exit_dt.append(df_sp_norm.index[i])
                init_yn = 0
        
    if len(init_dt) > len(exit_dt):
        if len(init_dt) - len(exit_dt) > 1:
            print("error")
        else:
            init_dt = init_dt[:-1]
    
    ret_list = []
    long_ret_list = []
    short_ret_list = []
    cum_ret = 1
    for i in range(len(init_dt)):
        dt_1 = init_dt[i]
        dt_2 = exit_dt[i]
        
        prc_1 = df.loc[dt_1]
        prc_2 = df.loc[dt_2]

        
        ret = prc_2/prc_1 - 1
        ret_ls = (ret * params_wt).sum()
        ret_list.append(ret_ls)        
        cum_ret *= (1+ret_ls)
        
        long_wt = [x if x >= 0 else 0 for x in params_wt]
        long_ret = (ret * long_wt).sum()
        long_ret_list.append(long_ret)
        
        short_wt = [x if x < 0 else 0 for x in params_wt]
        short_ret = (ret * short_wt).sum()
        short_ret_list.append(short_ret)
        
        
    
    return cum_ret, init_dt, exit_dt, ret_list, long_ret_list, short_ret_list

# %%
sector_code_list = ['IKS005', 'IKS006', 'IKS007', 'IKS008', 'IKS009', 'IKS010', 'IKS011', 'IKS012', 
                    'IKS013', 'IKS014', 'IKS015', 'IKS016', 'IKS017', 'IKS018', 'IKS019', 'IKS020', 
                    'IKS024', 'IKS025', 'IKS026']

# %%
sector_name_list = ['음식료품', '섬유의복', '종이목재', '화학', '의약품', '비금속광물', '철강금속', 
                    '기계', '전기전자', '의료정밀', '운수장비', '유통업', '전기가스업', '건설업', 
                    '운수창고업', '통신업', '증권', '보험업', '서비스업']

# %%
dict_sector_name = dict(zip(sector_code_list, sector_name_list))

# %%
i = 0.70
cap_hurdle = 200 * 1000000000
max_stk_cnt = 10

base_d = dt_m[int(np.round(len(dt_m)*i,0))]
train_begin_dt = dt_m[0]
train_end_dt = base_d

cap_filter = df_mktcap.copy()
cap_filter = cap_filter[cap_filter['BASE_D'] == base_d]
cap_filter = cap_filter[cap_filter['MKTCAP'] > cap_hurdle]
cap_filter.sort_values('MKTCAP', ascending = False, inplace = True)

dict_train = {}
dict_test = {}
dict_stk = {}

for sector_code in sector_code_list:
    
    sql_const = f'''
                SELECT TRD_DT, CONCAT('A',STK_CD) COMP_CD, STK_NM_KOR COMP_NM
                FROM TS_STK_ISSUE
                WHERE 1=1
                AND KS200_TYP = 1
                AND TRD_DT = '{base_d}'
                AND KSC_CD = '{sector_code}'
    '''

    df_const = pd.read_sql(sql_const, conn_wisefn)

    df_train = df_prc_raw.copy()
    df_train = df_train[df_train['TRD_DT'] >= train_begin_dt]
    df_train = df_train[df_train['TRD_DT'] <= train_end_dt]
    df_train = df_train[df_train['COMP_CD'].isin(df_const['COMP_CD'])]
    df_train = df_train.sort_values(by = ['TRD_DT','COMP_CD'])
    #stk_list = sorted(list(set(df_train['COMP_CD'])))


    df_train = df_train.pivot(index = 'TRD_DT', columns = 'COMP_CD')
    df_train = df_train.droplevel(axis = 1, level = 0)
    #df_train = df_train[stk_list]
    df_train.dropna(axis=1, inplace=True)
    stk_list = sorted(list(df_train.columns))
    
    # 시가총액 필터링
    stk_list = cap_filter[cap_filter['COMP_CD'].isin(stk_list)]['COMP_CD'][:max_stk_cnt].to_list()

    df_train = df_train[stk_list]
    
    df_test = df_prc_raw.copy()
    df_test = df_test[df_test['TRD_DT'] >= train_end_dt]
    #df_test = df_prc[df_prc['TRD_DT'] <= train_end_dt]
    df_test = df_test[df_test['COMP_CD'].isin(df_const['COMP_CD'])]
    df_test = df_test.sort_values(by = ['TRD_DT','COMP_CD'])

    df_test = df_test.pivot(index = 'TRD_DT', columns = 'COMP_CD')
    df_test = df_test.droplevel(axis = 1, level = 0)
    df_test = df_test[stk_list]
    
    dict_train[sector_code] = df_train
    dict_test[sector_code] = df_test
    dict_stk[sector_code] = stk_list

# %%
mp.cpu_count()
# Out:
# 16

# %%
# Out:
# 2023-12-06 10:43:07,922	INFO worker.py:1664 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.8', ray_version='2.8.0', ray_commit='105355bd253d6538ed34d331f6a4bdf0e38ace3a', protocol_version=None)

# %%
optimized_params = {}

for sector_code in sector_code_list:
    
    print(f'섹터: {dict_sector_name[sector_code]}')
    print(' ')
    
    df_train = dict_train[sector_code]
    df_test = dict_test[sector_code]
    stk_list = dict_stk[sector_code]
    
    if len(stk_list) == 0:
        continue
    
    
    print(f'  Train set: {train_begin_dt} ~ {train_end_dt}')
    print(f'  Test set: {train_end_dt} ~ {max(df_test.index)}')
    print(' ')
    print(f'  유전 알고리즘 시작')
    n_generation = 200
    population = 1000
    best_sample = int(population/4)
    lucky_few = int(population/4)
    prob1 = 0.01
    #prob2 = 0.01
    alpha = 0.10
    r_param = 4
    param_length = len(stk_list)

    pop = generate_pop(df_train, size = population, length = param_length)

    best_gene = []
    best_perf = []

    g = 0

    while True:

        pop_sorted = compute_performance(df_train, pop)

        survivors = select_survivors(pop_sorted, best_sample, lucky_few, param_length, df_train)

        children = create_children(df_train, survivors, population, alpha, r_param)

        new_generation = mutate_pop(children, prob1)

        if len(new_generation) < population:
            #print(f'  세대수 부족: {len(new_generation)}')
            break

        fixed_generation = fix_1(new_generation, df_train, param_length)

        pop = fixed_generation
        best_gene.append(pop_sorted[0][0])
        best_perf.append(pop_sorted[0][1])


        print(f'====== {g}th generation ends ======')
        print(pop_sorted[0])


        pop_wt = [x[0][3:] for x in pop_sorted]
        dist_wt = [sum([(x-y)**2 for (x,y) in zip(pop_wt[0],z)]) for z in pop_wt]
        hurdle = 0.025
        dist_wt_hurdle = [1 for x in dist_wt if x < hurdle]

        print(f'    최다 출현 개체수: {sum(dist_wt_hurdle)}')
        if sum(dist_wt_hurdle) > population * 0.7:
            break

        g += 1

        if g > n_generation:
            break

        print(' ')

    print(f'  유전 알고리즘 종료')
    print(' ')
    
    optimized_params[sector_code] = pop_sorted[0][0]
# Out:
# 섹터: 음식료품
#
#   Train set: 20100129 ~ 20191129
#   Test set: 20191129 ~ 20230927
#
#   유전 알고리즘 시작
# ====== 0th generation ends ======
# [[38, -2.332793077567054, 3.6552020542152093, 0.004048418622554776, 0.6056526430176735, -0.049824036974887534, 0.036443606813192676, -0.14433042173603947, -0.026834891484390378, -0.3255009950026487, 0.31462435225464963, 0.03923097929192942, -0.45350965480203387], 11.583488234556828]
#     최다 출현 개체수: 1
#
# ====== 1th generation ends ======
# [[409, -0.8535618689723088, 3.3035267390742087, -0.07372638171098801, 0.4431911126287841, -0.03605267432756199, -0.15042809518717232, 0.16870633535812213, -0.5138713917906448, -0.05296335421021835, 0.3443916234129604, -0.17295810277341447, 0.04371092860013343], 8.33186266162136]
#     최다 출현 개체수: 1
#
# ====== 2th generation ends ======
# [[119, -0.9657810323784586, 3.206865221378426, -0.40276395767194545, 0.10046670132501333, 0.007480024022269133, 0.07336469679764215, -0.03578993849637611, -0.022236573443724757, 0.08608515871733265, 0.5790303360390192, -0.5392095303879536, 0.15357308309872356], 17.8996599992533]
#     최다 출현 개체수: 1
#
# ====== 3th generation ends ======
# [[223, -1.6721772253513039, 2.781204156428979, -0.07705656889700935, -0.1563515549425231, 0.09854394455727816, -0.08492354179804959, -0.22038854220102905, 0.06369604283363521, -0.1502688846197273, 0.5342246660645863, -0.3110109075416615, 0.3035353465445003], 8.636224882111765]
#     최다 출현 개체수: 1
#
# ====== 4th generation ends ======
# [[220, -0.6960526554511386, 2.876083093371033, 0.11441653627061485, 0.008343468384895058, 0.12299876574855015, 0.3001123213532144, -0.11593170794834813, -0.06152775719427732, -0.02753518912767487, 0.26866035084990925, -0.7950053457296997, 0.18546855739281623], 11.980535589047143]
#
# ====== 4th generation ends ======
# [[197, -1.4450316882718899, 3.5031782306017116, -0.9156700565662187, 1.0, -0.08432994343378124], 15.774909927568187]
#     최다 출현 개체수: 50
#
# ====== 5th generation ends ======
# [[161, -1.1507322128662245, 3.1897243481156337, -0.4835824673191526, 1.0, -0.5164175326808473], 17.99637354286256]
#     최다 출현 개체수: 183
#
# ====== 6th generation ends ======
# [[167, -0.951151987911864, 3.1579516237711864, -0.5300866362680408, 1.0, -0.4699133637319593], 16.45703901969753]
#     최다 출현 개체수: 117
#
# ====== 7th generation ends ======
# [[181, -1.3377285894081228, 3.257220778792474, -0.5826207606435562, 1.0, -0.41737923935644383], 17.57345157654163]
#     최다 출현 개체수: 60
#
# ====== 8th generation ends ======
# [[161, -1.2154286908424636, 3.2681830005210775, -0.6212320177762959, 1.0, -0.37876798222370417], 17.896056791381042]
#     최다 출현 개체수: 50
#
# ====== 9th generation ends ======
# [[199, -1.4783142623597945, 3.5470745381610516, -0.7805871225279123, 1.0, -0.21941287747208774], 17.36558723648944]
#     최다 출현 개체수: 16
#
# ====== 10th generation ends ======
# [[175, -1.507058070832444, 3.491322461140932, -0.7315418936483681, 1.0, -0.268458106351632], 17.49386085688677]
#     최다 출현 개체수: 35
#
# ====== 11th generation ends ======
# [[175, -1.4120074955349267, 3.4742701105471534, -0.6917970994280097, 1.0, -0.3082029005719902], 17.65677733354949]
#     최다 출현 개체수: 33
#
# ====== 12th generation ends ======
# [[163, -1.4267746066114004, 3.163233359353977, -0.45744360014195956, 1.0, -0.5425563998580405], 18.461870930791882]
#     최다 출현 개체수: 196
#
# ====== 13th generation ends ======
# [[163, -1.371713084727931, 3.140378928234948, -0.5346707056835154, 1.0, -0.4653292943164846], 17.920392885317487]
#     최다 출현 개체수: 70
#
# ====== 14th generation ends ======
# [[163, -1.4874814042327, 3.4322816187104137, -0.7142970428194557, 1.0, -0.2857029571805444], 17.58694074175738]
#     최다 출현 개체수: 21
#
# ====== 15th generation ends ======
# [[163, -1.4764325747124103, 3.4339272005124535, -0.6203116233278135, 1.0, -0.3796883766721865], 17.86732127441917]
#     최다 출현 개체수: 35
#
# ====== 16th generation ends ======
# [[163, -1.2782720603253348, 3.0750687287902188, -0.4495641760011466, 1.0, -0.5504358239988534], 18.543389112544148]
#     최다 출현 개체수: 89
#
# ====== 17th generation ends ======
# [[163, -1.5685772754399032, 3.4899557907961154, -0.744318514756025, 1.0, -0.25568148524397494], 17.4197809621061]
#     최다 출현 개체수: 12
#
# ====== 18th generation ends ======
# [[163, -1.4491415694484577, 3.441082165953124, -0.6699136977375035, 1.0, -0.3300863022624964], 17.74592582213576]
#     최다 출현 개체수: 32
#
# ====== 19th generation ends ======
# [[200, -1.4708874219058605, 3.312177976733426, -0.8793867410240659, 1.0, -0.12061325897593406], 17.591132167414678]
#     최다 출현 개체수: 6
#
# ====== 20th generation ends ======
# [[163, -1.3497386133182547, 3.3966025994082085, -0.5920593092902671, 1.0, -0.407940690709733], 18.02613705089142]
#     최다 출현 개체수: 30
#
# ====== 21th generation ends ======
# [[26, -0.902454735854804, 2.6105633295709074, 0.7484193335099903, 0.25158066649000965, -0.07204637980833306, -0.9279536201916669], 38.96209818637228]
#     최다 출현 개체수: 12
#
# ====== 11th generation ends ======
# [[35, -0.865248310864194, 2.41075525736196, 1.0, -0.04720339121315169, -0.2189233069401785, -0.7338733018466699], 31.595801031002022]
#     최다 출현 개체수: 237
#
# ====== 12th generation ends ======
# [[38, -0.34426805099085067, 2.486489874494541, 0.9171975483601722, 0.08280245163982786, -0.34960557827363725, -0.6503944217263627], 28.663697067553805]
#     최다 출현 개체수: 155
#
# ====== 13th generation ends ======
# [[40, -1.308602978205069, 2.5124505761444014, 0.8972310839201008, 0.10276891607989931, -0.21461913251415735, -0.7853808674858427], 22.51280905789016]
#     최다 출현 개체수: 58
#
# ====== 14th generation ends ======
# [[31, -1.1889328251387408, 2.664694589448182, 0.9579006505324088, 0.04209934946759119, -0.18352792956680905, -0.816472070433191], 33.33855015634632]
#     최다 출현 개체수: 69
#
# ====== 15th generation ends ======
# [[31, -1.1889328251387408, 2.664694589448182, 0.9579006505324088, 0.04209934946759119, -0.18352792956680905, -0.816472070433191], 33.33855015634632]
#     최다 출현 개체수: 72
#
# ====== 16th generation ends ======
# [[20, -1.0994885215757297, 2.478617452764013, 1.0, -0.04207889777696622, -0.2720157878648667, -0.6859053143581672], 29.43805363114725]
#     최다 출현 개체수: 500
#
# ====== 17th generation ends ======
# [[25, -1.2406548571477976, 2.6729853202430394, 0.801360768242509, 0.198639231757491, -0.2960362175763097, -0.7039637824236903], 28.59739512257574]
#     최다 출현 개체수: 41
#
# ====== 18th generation ends ======
# [[30, -1.0430125118619662, 2.600778902862137, 0.7680946271998664, 0.23190537280013357, -0.32037816743067066, -0.6796218325693293], 37.63441834399123]
#     최다 출현 개체수: 41
#
# ====== 19th generation ends ======
# [[34, -1.3227907259268232, 2.5968710766868934, 0.9284908179454964, 0.07150918205450364, -0.3316253615944331, -0.6683746384055668], 27.620229157263143]
#     최다 출현 개체수: 284
#
# ====== 20th generation ends ======
# [[28, -0.9300156118186218, 2.438279655659229, 0.7827931836326778, 0.21720681636732225, -0.22391060026394946, -0.7760893997360504], 32.99795079283775]
#     최다 출현 개체수: 20
#
# ====== 21th generation ends ======
# [[35, -1.1705180092713265, 2.731199606222459, 1.0, -0.006930255257220878, -0.2260725792973776, -0.7669971654454015], 34.021440134710474]
#     최다 출현 개체수: 265
#
# ====== 22th generation ends ======
# ...
#     최다 출현 개체수: 32
#
# ====== 8th generation ends ======
# [[143, -0.421496794988443, 2.543166219831071, 0.01068532401121285, 0.07001502779128192, 0.9192996481975052, -1.0], 10.121516015333812]
#     최다 출현 개체수: 55
#
# ====== 9th generation ends ======
# [[137, -0.7177459424365413, 2.5819964147838825, 0.013198738331125583, -0.02537767821062239, 0.9868012616688744, -0.9746223217893776], 8.703646173776677]
#     최다 출현 개체수: 45
#
# ====== 10th generation ends ======
# [[116, -0.8150694221796919, 2.63998739809867, 0.022295108267729624, -0.025463271472091414, 0.9777048917322704, -0.9745367285279087], 9.458393708386465]
#     최다 출현 개체수: 55
#
# ====== 11th generation ends ======
# [[121, -0.8729775805983907, 2.421510180136298, -0.08018738923228408, 0.014402575352650954, 0.985597424647349, -0.9198126107677159], 9.910631304056476]
#     최다 출현 개체수: 79
#
# ====== 12th generation ends ======
# [[114, -0.9398050067028152, 2.4698062068269993, -0.04737892141641213, -0.00035801954050631755, 1.0, -0.9522630590430816], 9.549191045495979]
#     최다 출현 개체수: 81
#
# ====== 13th generation ends ======
# [[112, -0.8594551845138997, 2.441062980257712, -0.035940513141209836, 0.01660584115149142, 0.9833941588485087, -0.9640594868587902], 9.47066340246767]
#     최다 출현 개체수: 113
#
# ====== 14th generation ends ======
# [[112, -0.8708360562672122, 2.3924340418928107, -0.06334902823036835, 0.016702377548738254, 0.9832976224512617, -0.9366509717696316], 9.072975943321856]
#     최다 출현 개체수: 121
#
# ====== 15th generation ends ======
# [[116, -0.9030885619982719, 2.4333985751664526, -0.06550213632853234, 0.003948500894876141, 0.9960514991051238, -0.9344978636714676], 9.252173503177259]
#     최다 출현 개체수: 113
#
# ====== 16th generation ends ======
# [[113, -0.8802026829281611, 2.4790786810950345, -0.06501615339730843, 0.016848628787868764, 0.9831513712121311, -0.9349838466026915], 9.534117951779226]
#     최다 출현 개체수: 135
#
# ====== 17th generation ends ======
# [[115, -0.8844259570369879, 2.3765489310619476, -0.01132603025858786, -3.9479768862852446e-05, 1.0, -0.9886344899725492], 9.695811901873132]
#     최다 출현 개체수: 134
#
# ====== 18th generation ends ======
# [[113, -0.8419482301512808, 2.36983093246645, -0.01769391052429117, 0.004067599412388538, 0.9959324005876115, -0.9823060894757089], 8.441888780559813]
#     최다 출현 개체수: 139
#
# ====== 19th generation ends ======
# [[111, -0.8590239796257643, 2.3796683859168377, -0.016260888894341793, 0.004333716900432151, 0.9956662830995678, -0.9837391111056581], 9.6945022064059]
#     최다 출현 개체수: 107
#
# ====== 20th generation ends ======
# [[113, -0.8777411533351126, 2.4318556746597757, -0.03956172625256594, -0.01544885803598945, 1.0, -0.9449894157114447], 8.979413013846566]
#     최다 출현 개체수: 51
#
# ====== 21th generation ends ======
# [[115, -0.9878727405744762, 2.5189082609785403, -0.019304077830454187, 0.18992093299336682, 0.8100790670066331, -0.9806959221695458], 8.03353846686678]
#     최다 출현 개체수: 768
#   유전 알고리즘 종료
#
# 섹터: 통신업
#
#   Train set: 20100129 ~ 20191129
#   Test set: 20191129 ~ 20230927
#
#   유전 알고리즘 시작
# ====== 0th generation ends ======
# [[344, -1.8441300393254632, 3.074325729207255, -0.8280702009172073, -0.1719297990827927, 1.0], 3.663917004536431]
#     최다 출현 개체수: 31
#
# ====== 1th generation ends ======
# [[191, -0.3414269078757416, 1.4214638451572519, -0.5970261200718143, -0.4029738799281858, 1.0], 3.9326423787856144]
#     최다 출현 개체수: 78
#
# ====== 2th generation ends ======
# [[379, -0.026511842255340756, 2.7411633525824763, -0.47177875740520825, -0.5282212425947918, 1.0], 4.330696749256657]
#     최다 출현 개체수: 133
#
# ====== 3th generation ends ======
# [[208, -0.7044987751983243, 2.4661373425746054, -0.3072559603182304, -0.6927440396817697, 1.0], 4.262134504933034]
#     최다 출현 개체수: 212
#
# ====== 4th generation ends ======
# [[393, -0.07076561634033651, 2.7276770135325323, -0.40260969546822356, -0.5973903045317766, 1.0], 5.075533651519261]
#     최다 출현 개체수: 222
#
# ====== 5th generation ends ======
# [[384, -0.2777858300724658, 2.7132370645661466, -0.29077528041752704, -0.7092247195824728, 1.0], 5.054865294651308]
#     최다 출현 개체수: 326
#
# ====== 6th generation ends ======
# [[407, -0.41880135870080026, 2.492793241010623, -0.10241113688108067, -0.8975888631189193, 1.0], 4.751593612447288]
#     최다 출현 개체수: 334
#
# ====== 7th generation ends ======
# [[268, -0.6253589543589444, 2.4962509861447586, -0.29728438008367986, -0.7027156199163201, 1.0], 4.381053241656091]
#     최다 출현 개체수: 336
#
# ====== 8th generation ends ======
# [[138, -0.9871334701790974, 2.4696238011589093, -0.0863141791168628, -0.9136858208831372, 1.0], 4.499703203002226]
#     최다 출현 개체수: 499
#
# ====== 9th generation ends ======
# [[134, -0.8499631433693325, 2.4293914410654978, -0.0654213975671597, -0.9345786024328402, 1.0], 4.295895788336642]
#     최다 출현 개체수: 496
#
# ====== 10th generation ends ======
# [[139, -0.7363003291775377, 2.420093676373338, -0.007113918210317985, -0.992886081789682, 1.0], 4.594072361831726]
#     최다 출현 개체수: 323
#
# ====== 11th generation ends ======
# [[278, -0.5146004183088918, 2.4762975264684983, -0.23447110561748913, -0.7655288943825109, 1.0], 4.326572114166714]
#     최다 출현 개체수: 481
#
# ====== 12th generation ends ======
# [[128, -0.6979687721882891, 2.392383134395522, -0.10510373339178679, -0.8948962666082132, 1.0], 4.236972167904015]
#     최다 출현 개체수: 702
#   유전 알고리즘 종료
#
# 섹터: 증권
#
#   Train set: 20100129 ~ 20191129
#   Test set: 20191129 ~ 20230927
#
#   유전 알고리즘 시작
# ====== 0th generation ends ======
# [[39, -0.12035212271834084, 3.152836043882987, -0.6489286771025703, -0.35107132289742976, 0.045785843459883444, 0.9542141565401165], 9.605065248655428]
#     최다 출현 개체수: 3
#
# ====== 1th generation ends ======
# [[37, -0.6059386547458063, 2.852950618882883, -0.4340640224723066, -0.2921070913039147, -0.2738288862237787, 1.0], 8.367324942563531]
#     최다 출현 개체수: 18
#
# ====== 2th generation ends ======
# [[40, -1.406968175197219, 2.828700609290811, -0.5004473645436436, -0.27412032601115327, -0.2254323094452032, 1.0], 8.299579631880086]
#     최다 출현 개체수: 18
#
# ====== 3th generation ends ======
# [[20, -2.0170369225353872, 3.239770377859129, -1.0, 0.09495918936025395, 0.10463772240442148, 0.8004030882353245], 6.814224854440378]
#     최다 출현 개체수: 12
#
# ====== 4th generation ends ======
# [[56, -0.6779988035212081, 2.905497879964005, -0.5363536656466784, -0.034960872019499996, -0.42868546233382165, 1.0], 7.976874679040399]
#     최다 출현 개체수: 32
# ====== 5th generation ends ======
# [[65, -0.7566842671268819, 3.2381400021851188, -0.5316029583572031, 0.012047985353573355, -0.4683970416427969, 0.9879520146464267], 9.621755962658012]
#     최다 출현 개체수: 28
#
# ====== 6th generation ends ======
# [[68, -1.1983251036668792, 3.198516486624305, -0.8703849912213867, -0.011117587508438437, -0.11849742127017485, 1.0], 10.553844926428333]
#     최다 출현 개체수: 32
#
# ====== 7th generation ends ======
# [[59, -0.9675490199519164, 3.1753017511715584, -0.7289410193907121, 0.09809802773249361, -0.27105898060928785, 0.9019019722675063], 10.087723461907736]
#     최다 출현 개체수: 103
#
# ====== 8th generation ends ======
# [[65, -1.4352876712621112, 3.1695262675320555, -0.8286891104823908, 0.0313042566163555, -0.1713108895176092, 0.9686957433836445], 10.681239221012923]
#     최다 출현 개체수: 72
#
# ====== 9th generation ends ======
# [[63, -0.994291972196619, 3.0554289966506305, -0.6713861054929277, -0.01392754210218702, -0.31468635240488513, 1.0], 12.118333404287952]
#     최다 출현 개체수: 171
#
# ====== 10th generation ends ======
# [[61, -1.1308445450555442, 3.0554803220755633, -0.7093176117081329, -0.026012173843092734, -0.2646702144487744, 1.0], 11.869550548263257]
#     최다 출현 개체수: 238
#
# ====== 11th generation ends ======
# [[61, -1.0755801321099097, 3.110325083556245, -0.6978133367924622, -0.04158175948852413, -0.26060490371901374, 1.0], 12.166722542748424]
#     최다 출현 개체수: 289
#
# ====== 12th generation ends ======
# [[61, -1.3425436598270615, 3.041493090902298, -0.7402753780109937, 0.03020074154228219, -0.2597246219890063, 0.9697992584577177], 12.109734555107336]
#     최다 출현 개체수: 560
#
# ====== 13th generation ends ======
# [[63, -0.9581726198989257, 3.1286577097125785, -0.7039775294804627, 0.0004559045328205904, -0.2960224705195374, 0.9995440954671794], 12.434283959161228]
#     최다 출현 개체수: 642
#
# ====== 14th generation ends ======
# [[63, -1.1536494216817477, 3.174008219074388, -0.7528014880117083, 0.008401668285376805, -0.24719851198829165, 0.9915983317146232], 12.265557526830367]
#     최다 출현 개체수: 655
#
# ====== 15th generation ends ======
# [[60, -1.069917338678604, 3.124318699174032, -0.7295627165461098, 0.007771108204453656, -0.2704372834538903, 0.9922288917955463], 12.33259054582679]
#     최다 출현 개체수: 786
#   유전 알고리즘 종료
#
# 섹터: 보험업
#
#   Train set: 20100129 ~ 20191129
#   Test set: 20191129 ~ 20230927
#
#   유전 알고리즘 시작
# ====== 0th generation ends ======
# [[37, -0.8493395601486267, 0.8745597751483465, -0.3754247455271341, 1.0, -0.6245752544728659], 8.80973203233609]
#     최다 출현 개체수: 51
#
# ====== 1th generation ends ======
# [[42, -0.7114231746415067, 0.6426566948932809, -0.4604934451814639, 1.0, -0.5395065548185362], 6.9719930913281525]
#     최다 출현 개체수: 59
#
# ====== 2th generation ends ======
# [[20, -1.2122204559628902, 0.8483620920834287, -0.449586478906755, 1.0, -0.550413521093245], 9.246115518965755]
#     최다 출현 개체수: 61
#
# ====== 3th generation ends ======
# [[37, -0.8681292315520799, 0.6902554570079835, 0.2823769613871803, -1.0, 0.7176230386128196], 8.883775513694365]
#     최다 출현 개체수: 24
#
# ====== 4th generation ends ======
# [[35, -0.9628620002239124, 0.3681767422447344, -0.6112027207081526, 1.0, -0.3887972792918474], 9.5483419474273]
#     최다 출현 개체수: 148
#
# ====== 5th generation ends ======
# [[31, -0.5964282628615294, 0.6226065100809468, -0.513913553981684, 1.0, -0.4860864460183161], 11.480031154702315]
#     최다 출현 개체수: 186
#
# ====== 6th generation ends ======
# [[30, -1.08396406426014, 0.7534044221529189, -0.5215610925764572, 1.0, -0.47843890742354267], 10.150330219643541]
#     최다 출현 개체수: 291
#
# ====== 7th generation ends ======
list_summary = []

for sector_code in sector_code_list:
    
    if len(dict_stk[sector_code]) == 0:
        continue
        
    params = optimized_params[sector_code]
    df_train = dict_train[sector_code]
    df_test = dict_test[sector_code]
    
    temp_train = simulation_func(df_train, params)
    temp_test = simulation_func(df_test, params)
    
    ret_train = pd.DataFrame([temp_train[1], temp_train[2], temp_train[3],temp_train[4],temp_train[5]], 
                             index = ['init_dt','exit_dt','ls','long','short']).T
    ret_test = pd.DataFrame([temp_test[1], temp_test[2], temp_test[3],temp_test[4],temp_test[5]], 
                            index = ['init_dt','exit_dt','ls','long','short']).T
    
    ret_train['init_dt'] = pd.to_datetime([str(int(x)) for x in ret_train['init_dt']])
    ret_train['exit_dt'] = pd.to_datetime([str(int(x)) for x in ret_train['exit_dt']])
    ret_test['init_dt'] = pd.to_datetime([str(int(x)) for x in ret_test['init_dt']])
    ret_test['exit_dt'] = pd.to_datetime([str(int(x)) for x in ret_test['exit_dt']])
    
    ret_train['holding period'] = ret_train['exit_dt'] - ret_train['init_dt']
    ret_test['holding period'] = ret_test['exit_dt'] - ret_test['init_dt']
    
    result_train[sector_code] = ret_train
    result_test[sector_code] = ret_test
    
    
    case_train = len(ret_train)
    
    if case_train == 0:
        hr_train = 0
    else:
        hr_train = len(ret_train[ret_train['ls'] >= 0])/len(ret_train)
        
    cumret_train = temp_train[0]
    
    case_test = len(ret_test)
    
    if case_test == 0:
        hr_test = 0
    else:
        hr_test = len(ret_test[ret_test['ls'] >= 0])/len(ret_test)
    
    cumret_test = temp_test[0]
                   
    
    list_summary.append([case_train, hr_train, cumret_train, case_test, hr_test, cumret_test])

# %%
df_summary = pd.DataFrame(list_summary, columns = ['cnt_train','hr_train','ret_train','cnt_test','hr_test','ret_test'], 
                          index = [dict_sector_name[x] for x in result_train.keys()])
df_summary['keys'] = result_train.keys()

# %%
df_summary
# Out:
#        cnt_train  hr_train  ret_train  cnt_test   hr_test  ret_test    keys
# 음식료품           2  1.000000  23.014734         0  0.000000  1.000000  IKS005
# 섬유의복           1  1.000000  15.342328         1  1.000000  1.081481  IKS006
# 화학             2  0.500000   6.724314         0  0.000000  1.000000  IKS008
# 의약품            3  1.000000  15.108381         0  0.000000  1.000000  IKS009
# 비금속광물          5  1.000000  16.251485         0  0.000000  1.000000  IKS010
# 철강금속           6  1.000000   4.863068         1  0.000000  0.730227  IKS011
# 기계            18  0.833333  34.862066         6  0.666667 -2.699022  IKS012
# 전기전자           8  1.000000  11.298945         2  1.000000  1.320821  IKS013
# 운수장비           6  1.000000   9.474732         0  0.000000  1.000000  IKS015
# 유통업            2  1.000000  15.262218         2  1.000000  1.382372  IKS016
# 전기가스업          2  1.000000   2.904354         0  0.000000  1.000000  IKS017
# 건설업           12  0.916667   7.111276         1  0.000000  0.482522  IKS018
# 운수창고업          8  0.750000   8.033538         1  1.000000  1.665510  IKS019
# 통신업            8  1.000000   4.236972         2  0.000000  0.738296  IKS020
# 증권             8  1.000000  12.332591         2  1.000000  1.625825  IKS024
# 보험업           84  0.845238  12.033489        20  0.700000  1.341297  IKS025
-- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.8', ray_version='2.8.0', ray_commit='105355bd253d6538ed34d331f6a4bdf0e38ace3a', protocol_version=None)

# %%
filtered_sector = []
for sector_code in dict_stk.keys():
    if len(dict_stk[sector_code]) < 2:
        pass
    else:
        filtered_sector.append(sector_code)

# %%
dict_train_2 = {k:dict_train[k] for k in filtered_sector if k in dict_train}
dict_test_2 = {k:dict_test[k] for k in filtered_sector if k in dict_test}
dict_stk_2 = {k:dict_stk[k] for k in filtered_sector if k in dict_stk}
dict_sector_name_2 = {k:dict_sector_name[k] for k in filtered_sector if k in dict_sector_name}

# %%
@ray.remote
def get_optimized_params(sector_code, dict_train, dict_test, dict_stk, dict_sector_name):
    
    print(f'섹터: {dict_sector_name[sector_code]}')
    #print(' ')
    
    df_train = dict_train[sector_code]
    df_test = dict_test[sector_code]
    stk_list = dict_stk[sector_code]
    
    
    #print(f'  Train set: {train_begin_dt} ~ {train_end_dt}')
    #print(f'  Test set: {train_end_dt} ~ {max(df_test.index)}')
    #print(' ')
    #print(f'  유전 알고리즘 시작')
    n_generation = 200
    population = 1000
    best_sample = int(population/4)
    lucky_few = int(population/4)
    prob1 = 0.01
    #prob2 = 0.01
    alpha = 0.10
    r_param = 4
    param_length = len(stk_list)

    pop = generate_pop(df_train, size = population, length = param_length)

    best_gene = []
    best_perf = []

    g = 0

    while True:

        pop_sorted = compute_performance(df_train, pop)

        survivors = select_survivors(pop_sorted, best_sample, lucky_few, param_length, df_train)

        children = create_children(df_train, survivors, population, alpha, r_param)

        new_generation = mutate_pop(children, prob1)

        if len(new_generation) < population:
            #print(f'  세대수 부족: {len(new_generation)}')
            break

        fixed_generation = fix_1(new_generation, df_train, param_length)

        pop = fixed_generation
        best_gene.append(pop_sorted[0][0])
        best_perf.append(pop_sorted[0][1])


        #print(f'====== {g}th generation ends ======')
        print(pop_sorted[0])


        pop_wt = [x[0][3:] for x in pop_sorted]
        dist_wt = [sum([(x-y)**2 for (x,y) in zip(pop_wt[0],z)]) for z in pop_wt]
        hurdle = 0.025
        dist_wt_hurdle = [1 for x in dist_wt if x < hurdle]

        #print(f'    최다 출현 개체수: {sum(dist_wt_hurdle)}')
        if sum(dist_wt_hurdle) > population * 0.7:
            break

        g += 1

        if g > n_generation:
            break

        print(' ')

    #print(f'  유전 알고리즘 종료')
    #print(' ')
    
    return pop_sorted[0][0], g

# %%
futures = [get_optimized_params.remote(sector_code, dict_train_2, dict_test_2, dict_stk_2, dict_sector_name_2) for sector_code in filtered_sector]
# Out:
# (get_optimized_params pid=21128) 섹터: 음식료품
# (get_optimized_params pid=15808) 섹터: 섬유의복
# (get_optimized_params pid=30988) 섹터: 철강금속
# (get_optimized_params pid=31764) 섹터: 의약품
# (get_optimized_params pid=20192) 섹터: 기계
# (get_optimized_params pid=21100) 섹터: 비금속광물
# (get_optimized_params pid=25584) 섹터: 전기전자
# (get_optimized_params pid=19320) 섹터: 화학

# %%
t1 = datetime.datetime.today()
optimized_params = ray.get(futures)

t2 = datetime.datetime.today()

lt = (t2 - t1).seconds
# Out:
# (get_optimized_params pid=19320) [[154, -1.5414387687635984, 3.121944692455533, -0.02625450342969824, -0.1306188485031018, -0.20472161118305485, 1.0, -0.174836256276912, -0.207971920284389, -0.011033389528153803, -0.1939164875276597, -0.04336662570843671, -0.007280357558594027], 5.858937344619739]
# (get_optimized_params pid=19320)
# (get_optimized_params pid=19320)   [repeated 16x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (get_optimized_params pid=15808)   [repeated 16x across cluster]
# (get_optimized_params pid=15808)   [repeated 16x across cluster]
# (get_optimized_params pid=21128)   [repeated 10x across cluster]
# (get_optimized_params pid=15808)   [repeated 6x across cluster]
# (get_optimized_params pid=31764)   [repeated 6x across cluster]
# (get_optimized_params pid=30988)   [repeated 6x across cluster]
# (get_optimized_params pid=15808)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=25584)   [repeated 6x across cluster]
# (get_optimized_params pid=20192)   [repeated 6x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=21128)   [repeated 6x across cluster]
# (get_optimized_params pid=20192)   [repeated 6x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=21128)   [repeated 6x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=21128)   [repeated 6x across cluster]
# (get_optimized_params pid=25584)   [repeated 2x across cluster]
# (get_optimized_params pid=20192)   [repeated 6x across cluster]
# (get_optimized_params pid=21128)   [repeated 8x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 6x across cluster]
# (get_optimized_params pid=20192)   [repeated 6x across cluster]
# (get_optimized_params pid=21128)   [repeated 2x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=30988) [[185, -1.0539528427560327, 2.0735831386720984, -0.03603340470808332, 0.6407060323428809, -0.5709377688121015, 0.20116826376279234, 0.14989169109082812, 0.00823401280349868, -0.16033025271330345, -0.2326985737665117], 5.378738266111807]
# (get_optimized_params pid=30988)
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=21100)   [repeated 4x across cluster]
# (get_optimized_params pid=21128)   [repeated 2x across cluster]
# (get_optimized_params pid=20192)   [repeated 4x across cluster]
# (get_optimized_params pid=30988) [[170, -1.106523931084023, 2.170741359077427, -0.11837762367909715, 0.6743101920188659, -0.5013987035676896, 0.17894219806382686, 0.14674760991730743, -0.039150505765699325, -0.19403702812704754, -0.1470361388604663], 5.987898227922591]
# (get_optimized_params pid=30988)
# (get_optimized_params pid=21100)   [repeated 8x across cluster]
# (get_optimized_params pid=21128)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=30988) [[196, -1.0002453944533294, 2.3101038643734, -0.06689407134777084, 0.6154866643766591, -0.5284650467009371, 0.2510449058468863, 0.1334684297764545, -0.00828018453019504, -0.18169574785530587, -0.21466494956579127], 5.8920916753818915] [repeated 5x across cluster]
# (get_optimized_params pid=21128)   [repeated 7x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=21100)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 4x across cluster]
# (get_optimized_params pid=20192)   [repeated 6x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=21100)   [repeated 4x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=25584)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=31764)   [repeated 2x across cluster]
# (get_optimized_params pid=15808)   [repeated 4x across cluster]
# (get_optimized_params pid=21100) 섹터: 운수장비
# (get_optimized_params pid=30988) [[178, -1.1002907793848775, 2.474599726841078, -0.040428755966762396, 0.6641285080964161, -0.6217866576621043, 0.17314934036551996, 0.1614376829837604, 0.0012844685543035265, -0.16758242602818585, -0.17020216034294744], 6.419614391032378] [repeated 4x across cluster]
# (get_optimized_params pid=30988) 섹터: 유통업
# (get_optimized_params pid=25584)   [repeated 2x across cluster]
# (get_optimized_params pid=31764)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=21128)   [repeated 4x across cluster]
# (get_optimized_params pid=30988)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=25584)   [repeated 2x across cluster]
# (get_optimized_params pid=15808)   [repeated 4x across cluster]
# (get_optimized_params pid=21128)   [repeated 2x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=31764)   [repeated 2x across cluster]
# (get_optimized_params pid=20192)   [repeated 6x across cluster]
# (get_optimized_params pid=30988)   [repeated 6x across cluster]
# (get_optimized_params pid=31764)   [repeated 4x across cluster]
# (get_optimized_params pid=25584)   [repeated 4x across cluster]
# (get_optimized_params pid=21128) 섹터: 전기가스업
# (get_optimized_params pid=30988)   [repeated 5x across cluster]
# (get_optimized_params pid=20192)   [repeated 4x across cluster]
# (get_optimized_params pid=31764) 섹터: 건설업
# (get_optimized_params pid=21128)   [repeated 5x across cluster]
# (get_optimized_params pid=21100)   [repeated 4x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=21128)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=20192) 섹터: 운수창고업
# (get_optimized_params pid=30988)   [repeated 7x across cluster]
# (get_optimized_params pid=15808) [[163, -1.6546199236274965, 3.5353078579749613, -0.09598079897643998, 1.0, -0.9040192010235599], 15.475553891797226]
# (get_optimized_params pid=15808)
# (get_optimized_params pid=31764)   [repeated 2x across cluster]
# (get_optimized_params pid=21128) 섹터: 통신업
# (get_optimized_params pid=19320)   [repeated 3x across cluster]
# (get_optimized_params pid=30988)   [repeated 6x across cluster]
# (get_optimized_params pid=31764)   [repeated 6x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=21100)   [repeated 2x across cluster]
# (get_optimized_params pid=15808) 섹터: 증권
# (get_optimized_params pid=25584)   [repeated 7x across cluster]
# (get_optimized_params pid=31764)   [repeated 2x across cluster]
# (get_optimized_params pid=21100)   [repeated 6x across cluster]
# (get_optimized_params pid=25584) [[158, -0.8159557844818953, 2.35765050080767, 0.09742889979892519, 0.6523094157814882, -0.03553273884458284, -0.3815837162598124, 0.08561174565030868, -0.14503792401659069, -0.03719940504135613, -0.3826035053011743, 0.16464993876927803, -0.018042710536483646], 12.937681625258616] [repeated 7x across cluster]
# (get_optimized_params pid=25584) 섹터: 보험업
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=21100)   [repeated 6x across cluster]
# (get_optimized_params pid=19320) [[283, -1.58675023502486, 3.0090080163449797, -0.04589820138606386, 0.40928059370318454, 0.056572821891531115, -0.0022145313684472064, 0.020801126351605553, -0.34287740970315245, 0.5133454580536787, -0.31193302709199267, -0.13324210168406142, -0.16383472876628258], 6.237557611925286] [repeated 7x across cluster]
# (get_optimized_params pid=19320) 섹터: 서비스업
# (get_optimized_params pid=31764) [[147, -0.9273440654721701, 1.6010599227000997, 0.3805025746463919, 0.22011548208062132, -0.05356231672582931, -0.9464376832741708, 0.39938194327298676], 5.368804965782859] [repeated 3x across cluster]
# (get_optimized_params pid=30988)   [repeated 5x across cluster]
# (get_optimized_params pid=15808)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=25584)   [repeated 2x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 6x across cluster]
# (get_optimized_params pid=20192)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=30988)   [repeated 2x across cluster]
# (get_optimized_params pid=31764)   [repeated 2x across cluster]
# (get_optimized_params pid=15808)   [repeated 8x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=21100)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 6x across cluster]
# (get_optimized_params pid=25584)   [repeated 4x across cluster]
# (get_optimized_params pid=30988)   [repeated 2x across cluster]
# (get_optimized_params pid=21100)   [repeated 4x across cluster]
# (get_optimized_params pid=31764)   [repeated 4x across cluster]
# (get_optimized_params pid=15808)   [repeated 2x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=25584)   [repeated 2x across cluster]
# (get_optimized_params pid=21128)   [repeated 4x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 6x across cluster]
# (get_optimized_params pid=21100) [[221, -1.6729426784255375, 2.0433042243512007, 0.04832535599523378, 0.045249541221614765, 0.06314221529946104, -0.13896817823652408, -0.05360809445171924, -0.7887385971071602, 0.05202450587964452, -0.018685130204596494, 0.5219054114400281, 0.2693529701640177], 9.09042596168651]
# (get_optimized_params pid=21128) [[132, -0.9721315672015046, 2.4089425902165367, 0.0018459827623991843, -1.0, 0.9981540172376009], 4.548166149295708]
# (get_optimized_params pid=21128)
# (get_optimized_params pid=31764)   [repeated 4x across cluster]
# (get_optimized_params pid=25584)   [repeated 6x across cluster]
# (get_optimized_params pid=30988)   [repeated 4x across cluster]
# (get_optimized_params pid=20192)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 6x across cluster]
# (get_optimized_params pid=30988)   [repeated 2x across cluster]
# (get_optimized_params pid=21128) [[136, -0.7854144933776851, 2.4279022115355358, -0.08502181356656732, -0.9149781864334326, 1.0], 4.431125760957764]
# (get_optimized_params pid=20192) [[166, -1.2221917027600289, 2.704959167806142, -0.10003478368029557, 1.0, -0.7972211489003413, -0.10274406741936318], 10.04320707015185]
# (get_optimized_params pid=20192)
# (get_optimized_params pid=25584)   [repeated 2x across cluster]
# (get_optimized_params pid=30988)   [repeated 6x across cluster]
# (get_optimized_params pid=20192)   [repeated 4x across cluster]
# (get_optimized_params pid=30988)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 5x across cluster]
# (get_optimized_params pid=20192)   [repeated 2x across cluster]
# (get_optimized_params pid=25584)   [repeated 3x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=20192)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=20192) [[157, -1.1127719232246138, 2.5846405281886016, -0.006475696123976076, 1.0, -0.8612675325020924, -0.13225677137393146], 13.173436903312526] [repeated 3x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=19320)   [repeated 6x across cluster]
# (get_optimized_params pid=19320)   [repeated 4x across cluster]
# (get_optimized_params pid=25584)   [repeated 4x across cluster]
# (get_optimized_params pid=19320)   [repeated 2x across cluster]
# (get_optimized_params pid=15808) [[41, -0.6241032252018629, 3.063242952353995, -0.7688138910720491, -0.033030287491028106, -0.19815582143692284, 1.0], 12.447297426782564]
# (get_optimized_params pid=19320) [[209, -1.3095334946345407, 2.021960906190503, 0.24884869282137234, 0.040467098297640045, 0.2665990968489072, 0.040897603652022364, 0.036108369788137966, 0.04393304332488872, 0.03572667097963261, 0.2613375487565799, 0.026081875530818907, -1.0], 10.359119336116713]
# (get_optimized_params pid=19320)
# (get_optimized_params pid=19320) [[182, -1.3603795477780307, 2.0949319155236803, 0.3588239581228332, 0.010034161727995136, 0.37197125434031253, 0.02652851990553204, 0.005022793840818806, 0.04176803336709476, 0.04621942308942832, 0.13094516624460886, 0.008686689361376643, -1.0], 10.326798310069277]
# (get_optimized_params pid=25584) [[28, -0.6464573570332134, 0.7575813978210495, -0.526502813060297, 1.0, -0.4734971869397031], 12.407359037460122]
# (get_optimized_params pid=25584)

# %%
lt/60
# Out:
# 27.0

# %%
optimized_params_1 = dict(zip(filtered_sector,[x[0] for x in optimized_params]))
optimized_params_2 = dict(zip(filtered_sector,[x[1] for x in optimized_params]))

# %%
result_train = {}
result_test = {}
list_summary = []

for sector_code in filtered_sector:
    
    if len(dict_stk[sector_code]) == 0:
        continue
        
    params = optimized_params_1[sector_code]
    df_train = dict_train[sector_code]
    df_test = dict_test[sector_code]
    
    temp_train = simulation_func(df_train, params)
    temp_test = simulation_func(df_test, params)
    
    ret_train = pd.DataFrame([temp_train[1], temp_train[2], temp_train[3],temp_train[4],temp_train[5]], 
                             index = ['init_dt','exit_dt','ls','long','short']).T
    ret_test = pd.DataFrame([temp_test[1], temp_test[2], temp_test[3],temp_test[4],temp_test[5]], 
                            index = ['init_dt','exit_dt','ls','long','short']).T
    
    ret_train['init_dt'] = pd.to_datetime([str(int(x)) for x in ret_train['init_dt']])
    ret_train['exit_dt'] = pd.to_datetime([str(int(x)) for x in ret_train['exit_dt']])
    ret_test['init_dt'] = pd.to_datetime([str(int(x)) for x in ret_test['init_dt']])
    ret_test['exit_dt'] = pd.to_datetime([str(int(x)) for x in ret_test['exit_dt']])
    
    ret_train['holding period'] = ret_train['exit_dt'] - ret_train['init_dt']
    ret_test['holding period'] = ret_test['exit_dt'] - ret_test['init_dt']
    
    result_train[sector_code] = ret_train
    result_test[sector_code] = ret_test
    
    
    case_train = len(ret_train)
    
    if case_train == 0:
        hr_train = 0
    else:
        hr_train = len(ret_train[ret_train['ls'] >= 0])/len(ret_train)
        
    cumret_train = temp_train[0]
    
    case_test = len(ret_test)
    
    if case_test == 0:
        hr_test = 0
    else:
        hr_test = len(ret_test[ret_test['ls'] >= 0])/len(ret_test)
    
    cumret_test = temp_test[0]
                   
    
    list_summary.append([case_train, hr_train, cumret_train, case_test, hr_test, cumret_test])

# %%
df_summary = pd.DataFrame(list_summary, columns = ['cnt_train','hr_train','ret_train','cnt_test','hr_test','ret_test'], 
                          index = [dict_sector_name[x] for x in result_train.keys()])
df_summary['keys'] = result_train.keys()

# %%
df_summary
# Out:
#        cnt_train  hr_train  ret_train  cnt_test   hr_test  ret_test    keys
# 음식료품           3  1.000000  21.913620         0  0.000000  1.000000  IKS005
# 섬유의복           1  1.000000  15.465863         1  1.000000  1.045376  IKS006
# 화학             2  1.000000   6.237558         0  0.000000  1.000000  IKS008
# 의약품            3  1.000000  10.062412         1  1.000000  1.223949  IKS009
# 비금속광물          5  1.000000  15.891223         0  0.000000  1.000000  IKS010
